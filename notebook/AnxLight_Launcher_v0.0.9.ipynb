# %% [markdown]
# <a href="https://colab.research.google.com/github/drf0rk/AnxLight/blob/main/notebook/AnxLight_Launcher_v0.0.9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Cell 1: AnxLight v3 Pre-Flight Setup (Robust)
# This cell ensures the repository is up-to-date and runs the main environment setup with enhanced logging and error handling.

import os
import subprocess
import sys
import time
import platform
from datetime import datetime

# --- Enhanced Logging ---
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_dir = f"/content/anxlight_logs_{timestamp}"
os.makedirs(log_dir, exist_ok=True)
log_file = f"{log_dir}/preflight_setup.log"

def log_message(message, level="INFO"):
    """Log a message to both console and log file"""
    timestamp_msg = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    formatted_msg = f"[{timestamp_msg}] [{level}] {message}"
    print(formatted_msg)
    with open(log_file, "a") as f:
        f.write(formatted_msg + "\n")

# --- Initial System Checks ---
log_message(f"Starting AnxLight v3 Pre-Flight Setup")
log_message(f"Python version: {sys.version}")
log_message(f"Platform: {platform.platform()}")

try:
    git_version = subprocess.check_output(["git", "--version"], text=True).strip()
    log_message(f"Git version: {git_version}")
except Exception as e:
    log_message(f"Git not found or not working properly: {e}", "ERROR")
    sys.exit(1)

# --- Step 1: Clone/Update the Repository ---
repo_path = '/content/AnxLight'
if not os.path.exists(repo_path):
    log_message(f"Cloning AnxLight repository to {repo_path}...")
    try:
        result = subprocess.run(
            ['git', 'clone', 'https://github.com/drf0rk/AnxLight.git', repo_path],
            check=True, capture_output=True, text=True, timeout=120
        )
        log_message(f"Clone successful.")
    except subprocess.TimeoutExpired:
        log_message("Git clone operation timed out after 120 seconds", "ERROR")
        sys.exit(1)
    except subprocess.CalledProcessError as e:
        log_message(f"FATAL: Failed to clone repository. Error: {e.stderr}", "ERROR")
        sys.exit(1)
else:
    log_message("AnxLight repository already exists. Pulling latest changes...")
    try:
        # Discard any local changes and pull the latest from the repo for a clean state
        subprocess.run(['git', '-C', repo_path, 'reset', '--hard', 'origin/main'], check=True, capture_output=True, text=True, timeout=60)
        pull_result = subprocess.run(['git', '-C', repo_path, 'pull'], check=True, capture_output=True, text=True, timeout=60)
        log_message(f"Pull result: {pull_result.stdout.strip()}")
    except subprocess.TimeoutExpired:
        log_message("Git pull operation timed out. Continuing with existing state.", "WARNING")
    except subprocess.CalledProcessError as e:
        log_message(f"WARNING: Failed to pull latest changes: {e.stderr}", "WARNING")

# --- Step 2: Set Environment ---
os.chdir(repo_path)
log_message(f"Current working directory: {os.getcwd()}")
os.environ['PROJECT_ROOT'] = repo_path
os.environ['ANXLIGHT_LOG_DIR'] = log_dir
log_message(f"PROJECT_ROOT set to: {os.environ['PROJECT_ROOT']}")

# --- Step 3: Execute the Pre-Flight Setup Script ---
pre_flight_script_path = os.path.join(repo_path, 'scripts', 'pre_flight_setup.py')
python_executable = sys.executable

if not os.path.exists(pre_flight_script_path):
    log_message(f"FATAL: Pre-flight script not found at {pre_flight_script_path}", "ERROR")
    sys.exit(1)

log_message(f"Executing Pre-Flight Setup Script: {pre_flight_script_path}")
preflight_log = f"{log_dir}/preflight_script_output.log"
log_message(f"Detailed script logs will be saved to: {preflight_log}")

try:
    with open(preflight_log, 'w') as log_f:
        process = subprocess.Popen(
            [python_executable, pre_flight_script_path],
            stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True
        )
        # Stream output to both console and log file
        for line in iter(process.stdout.readline, ''):
            print(line, end='')
            log_f.write(line)

        return_code = process.wait()

        if return_code != 0:
            log_message(f"Pre-flight setup failed with return code {return_code}", "ERROR")
            sys.exit(1)

    log_message("Pre-Flight Setup Script Finished Successfully")

except Exception as e:
    log_message(f"FATAL: An unexpected error occurred during pre-flight setup: {e}", "ERROR")
    import traceback
    log_message(traceback.format_exc(), "ERROR")
    sys.exit(1)

log_message("Cell 1 completed successfully. You can now run Cell 2.")
# Out:
# [2025-06-26 19:12:14] [INFO] Starting AnxLight v3 Pre-Flight Setup
# [2025-06-26 19:12:14] [INFO] Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# [2025-06-26 19:12:14] [INFO] Platform: Linux-6.1.123+-x86_64-with-glibc2.35
# [2025-06-26 19:12:14] [INFO] Git version: git version 2.34.1
# [2025-06-26 19:12:14] [INFO] AnxLight repository already exists. Pulling latest changes...
# [2025-06-26 19:12:15] [INFO] Pull result: Updating c4943e6..f559c90
# Fast-forward
#  scripts/main_gradio_app.py | 10 +++++++---
#  1 file changed, 7 insertions(+), 3 deletions(-)
# [2025-06-26 19:12:15] [INFO] Current working directory: /content/AnxLight
# [2025-06-26 19:12:15] [INFO] PROJECT_ROOT set to: /content/AnxLight
# [2025-06-26 19:12:15] [INFO] Executing Pre-Flight Setup Script: /content/AnxLight/scripts/pre_flight_setup.py
# [2025-06-26 19:12:15] [INFO] Detailed script logs will be saved to: /content/anxlight_logs_20250626_191214/preflight_script_output.log
# --- AnxLight Pre-Flight Setup Script v0.1.15 ---
# Project Root: /content/AnxLight
# Virtual Env Path: /content/AnxLight/anxlight_venv
#
# --- Ensuring essential system packages are installed (e.g., aria2) ---
#
# $ apt-get update -y
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# $ apt-get install -y aria2 curl unzip
# Reading package lists...
# Building dependency tree...
# Reading state information...
# aria2 is already the newest version (1.36.0-1).
# curl is already the newest version (7.81.0-1ubuntu1.20).
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# System packages installed/updated.
# Virtual environment already exists.
# Upgrading pip in existing VENV at /content/AnxLight/anxlight_venv...
#
# $ "/content/AnxLight/anxlight_venv/bin/python" -m pip install --upgrade pip
# Requirement already satisfied: pip in ./anxlight_venv/lib/python3.11/site-packages (25.1.1)
#
# --- Installing/Updating core dependencies with compatibility pins ---
#
# $ "/content/AnxLight/anxlight_venv/bin/pip" install --upgrade gradio==4.44.1 'pydantic>=2.9.0,<3.0.0' 'fastapi>=0.104.0' 'starlette>=0.27.0' huggingface-hub gdown nest_asyncio
# Requirement already satisfied: gradio==4.44.1 in ./anxlight_venv/lib/python3.11/site-packages (4.44.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in ./anxlight_venv/lib/python3.11/site-packages (2.11.7)
# Requirement already satisfied: fastapi>=0.104.0 in ./anxlight_venv/lib/python3.11/site-packages (0.115.14)
# Requirement already satisfied: starlette>=0.27.0 in ./anxlight_venv/lib/python3.11/site-packages (0.46.2)
# Collecting starlette>=0.27.0
#   Using cached starlette-0.47.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: huggingface-hub in ./anxlight_venv/lib/python3.11/site-packages (0.33.1)
# Requirement already satisfied: gdown in ./anxlight_venv/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: nest_asyncio in ./anxlight_venv/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (4.9.0)
# Requirement already satisfied: ffmpy in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.6.0)
# Requirement already satisfied: gradio-client==1.3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.28.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (3.10.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (2.3.1)
# Requirement already satisfied: orjson~=3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (3.10.18)
# Requirement already satisfied: packaging in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (2.3.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (10.4.0)
# Requirement already satisfied: pydub in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.12.0)
# Requirement already satisfied: semantic-version~=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (4.14.0)
# Requirement already satisfied: urllib3~=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (2.5.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio==4.44.1) (0.34.3)
# Requirement already satisfied: fsspec in ./anxlight_venv/lib/python3.11/site-packages (from gradio-client==1.3.0->gradio==4.44.1) (2025.5.1)
# Requirement already satisfied: websockets<13.0,>=10.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio-client==1.3.0->gradio==4.44.1) (12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.9.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.9.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.9.0) (0.4.1)
# Requirement already satisfied: idna>=2.8 in ./anxlight_venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio==4.44.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in ./anxlight_venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio==4.44.1) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./anxlight_venv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==4.44.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anxlight_venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio==4.44.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./anxlight_venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio==4.44.1) (2025.2)
# Requirement already satisfied: click>=8.0.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio==4.44.1) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio==4.44.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio==4.44.1) (14.0.0)
# Requirement already satisfied: filelock in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (3.18.0)
# Requirement already satisfied: requests in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (1.1.5)
# Requirement already satisfied: beautifulsoup4 in ./anxlight_venv/lib/python3.11/site-packages (from gdown) (4.13.4)
# Requirement already satisfied: certifi in ./anxlight_venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio==4.44.1) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in ./anxlight_venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio==4.44.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./anxlight_venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.44.1) (0.16.0)
# Requirement already satisfied: six>=1.5 in ./anxlight_venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.44.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./anxlight_venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./anxlight_venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./anxlight_venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in ./anxlight_venv/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub) (3.4.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./anxlight_venv/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
#
# --- Running WebUI Installers ---
# --- Running UI installer: ReForge.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/ReForge.py"
# --- AnxLight ReForge UI Installer Script (Note: ReForge development by Panchovix reportedly stopped) ---
# --- [ReForge.py] Step 1: Cloning WebUI from https://github.com/Panchovix/stable-diffusion-webui-reForge.git into /content/AnxLight/ReForge ---
# --- [ReForge.py] Directory /content/AnxLight/ReForge already exists. Assuming ReForge is already cloned. ---
# --- [ReForge.py] ReForge repository cloned. Further setup handled by its first launch. ---
# --- [ReForge.py] ReForge repository clone process finished. ---
# --- [ReForge.py] Downloading configuration files and extensions (review for ReForge compatibility) ---
# --- [ReForge.py] Cloning extensions into /content/AnxLight/ReForge/extensions (review for ReForge compatibility) ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Viewer' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [ReForge.py] Script finished ---
# --- Running UI installer: ComfyUI.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/ComfyUI.py"
# --- Running UI installer: A1111.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/A1111.py"
# --- AnxLight A1111 UI Installer Script ---
# --- [A1111.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip ---
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
#   To: /content/AnxLight/A1111.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
# >> Target directory: /content/AnxLight
# >> Target filename: A1111.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="A1111.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip"
# >> Aria2c download successful for A1111.zip
# --- [A1111.py] Step 2: Unzipping /content/AnxLight/A1111.zip to /content/AnxLight/A1111 ---
# --- [A1111.py] Step 3: Removing /content/AnxLight/A1111.zip ---
# --- [A1111.py] Unpack finished, proceeding to download configuration ---
# --- [A1111.py] Cloning extensions into /content/AnxLight/A1111/extensions ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Viewer' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'adetailer' already exists. Skipping clone.
# Extension 'SD-Couple' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [A1111.py] Script finished ---
# --- Running UI installer: SD-UX.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/SD-UX.py"
# --- AnxLight SD-UX UI Installer Script ---
# --- Note: Installation method and nature of 'SD-UX' needs verification. ---
# --- [SD-UX.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip (assuming zip archive) ---
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
#   To: /content/AnxLight/SD-UX.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# >> Target directory: /content/AnxLight
# >> Target filename: SD-UX.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="SD-UX.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip"
# >> Aria2c download successful for SD-UX.zip
# --- [SD-UX.py] Step 2: Unzipping /content/AnxLight/SD-UX.zip to /content/AnxLight/SD-UX ---
# --- [SD-UX.py] Step 3: Removing /content/AnxLight/SD-UX.zip ---
# --- [SD-UX.py] Basic unzip complete. If this is Stability-AI/StableStudio, further Node.js/Yarn setup is needed. ---
# --- [SD-UX.py] Unpack process finished. ---
# --- [SD-UX.py] Downloading generic configuration files (review for SD-UX compatibility) ---
# --- [SD-UX.py] Generic extension download step skipped/placeholder for SD-UX. Needs verification. ---
# --- [SD-UX.py] Script finished ---
# --- Running UI installer: Classic.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/Classic.py"
# --- AnxLight Classic UI Installer Script ---
# --- [Classic.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip ---
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
#   To: /content/AnxLight/Classic.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# >> Target directory: /content/AnxLight
# >> Target filename: Classic.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="Classic.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip"
# >> Aria2c download successful for Classic.zip
# --- [Classic.py] Step 2: Unzipping /content/AnxLight/Classic.zip to /content/AnxLight/Classic ---
# --- [Classic.py] Step 3: Removing /content/AnxLight/Classic.zip ---
# --- [Classic.py] Unpack finished, proceeding to download configuration ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'adetailer' already exists. Skipping clone.
# Extension 'SD-Couple' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [Classic.py] Download configuration finished, proceeding to apply module fixes ---
# --- [Classic.py] Applied fixes to /content/AnxLight/Classic/modules/cmd_args.py ---
# --- [Classic.py] Script finished ---
# --- Running UI installer: Forge.py ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/scripts/UIs/Forge.py"
#
# --- Verifying Environment Compatibility ---
#
# $ "/content/AnxLight/anxlight_venv/bin/python" "/content/AnxLight/temp_check_script.py"
# /content/AnxLight/temp_check_script.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# --- Checking package versions ---
# [OK] gradio: Found 4.44.1, meets ==4.44.1
# [OK] pydantic: Found 2.11.7, meets >=2.9.0,<3.0.0
# [OK] fastapi: Found 0.115.14, meets >=0.104.0
# [OK] starlette: Found 0.46.2, meets >=0.27.0
#
# All checked packages meet version requirements.
#
# --- Running pip check for dependency conflicts ---
#
# $ "/content/AnxLight/anxlight_venv/bin/pip" check
# No broken requirements found.
#
# --- Pre-Flight Setup Finished ---
# [2025-06-26 19:13:30] [INFO] Pre-Flight Setup Script Finished Successfully
# [2025-06-26 19:13:30] [INFO] Cell 1 completed successfully. You can now run Cell 2.

# %%
# @title Cell 2: AnxLight v3 Gradio App Launcher (Robust)
# This cell launches the main Gradio UI with enhanced process management, logging, and error detection.

import os
import sys
import subprocess
import time
import signal
import atexit
from datetime import datetime

# --- Enhanced Logging ---
log_dir = os.environ.get('ANXLIGHT_LOG_DIR', f"/content/anxlight_logs_{datetime.now().strftime('%Y%m%d_%H%M%S')}")
os.makedirs(log_dir, exist_ok=True)
gradio_log_file = f"{log_dir}/gradio_app.log"

def log_message(message, level="INFO"):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    formatted_msg = f"[{timestamp}] [{level}] {message}"
    print(formatted_msg)
    with open(gradio_log_file, "a") as f:
        f.write(formatted_msg + "\n")

log_message("Starting AnxLight v3 Launch Cell")

# --- Path Verification ---
project_root = os.environ.get('PROJECT_ROOT', '/content/AnxLight')
venv_python_path = os.path.join(project_root, 'anxlight_venv', 'bin', 'python')
main_gradio_script_path = os.path.join(project_root, 'scripts', 'main_gradio_app.py')

if not os.path.exists(venv_python_path):
    log_message(f"CRITICAL ERROR: Virtual environment not found at {venv_python_path}. Please run Cell 1.", "ERROR")
    sys.exit(1)

# --- Process Management ---
gradio_process = None

def cleanup_process():
    global gradio_process
    if gradio_process and gradio_process.poll() is None:
        log_message("Terminating Gradio process...")
        try:
            gradio_process.terminate()
            gradio_process.wait(timeout=5)
            log_message("Gradio process terminated gracefully.")
        except subprocess.TimeoutExpired:
            gradio_process.kill()
            log_message("Gradio process forcefully killed.")
        except Exception as e:
            log_message(f"Error during cleanup: {e}", "ERROR")

atexit.register(cleanup_process)

# --- Launch Gradio App ---
gradio_env = os.environ.copy()
gradio_env['PYTHONPATH'] = f"{os.path.join(project_root, 'modules')}:{project_root}:{os.path.join(project_root, 'scripts')}:{gradio_env.get('PYTHONPATH', '')}"
log_message(f"Launching: {main_gradio_script_path}")
log_message(f"Log file: {gradio_log_file}")

try:
    gradio_process = subprocess.Popen(
        [venv_python_path, main_gradio_script_path],
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True, env=gradio_env, cwd=project_root
    )
    log_message("Waiting for Gradio URL...")

    url_found = False
    start_time = time.time()
    timeout = 300 # 5 minutes
    url_patterns = ["Running on public URL:", "Public URL:"]

    for line in iter(gradio_process.stdout.readline, ''):
        print(line, end='')
        with open(gradio_log_file, "a") as f: f.write(line)

        if any(p in line for p in url_patterns):
            print("\n" + "="*60)
            print("          GRADIO IS RUNNING AND READY!")
            print("          Click the public URL above to open the UI.")
            print("="*60 + "\n")
            url_found = True
            break

        if time.time() - start_time > timeout:
            log_message(f"Timeout waiting for Gradio URL after {timeout} seconds.", "ERROR")
            break

    if url_found:
        # Stream the rest of the output indefinitely
        for line in iter(gradio_process.stdout.readline, ''):
            print(line, end='')
            with open(gradio_log_file, "a") as f: f.write(line)
    else:
        log_message("Gradio process finished or timed out before a URL was generated.", "ERROR")

except KeyboardInterrupt:
    log_message("Keyboard interrupt received. Shutting down.", "WARNING")
except Exception as e:
    log_message(f"An error occurred while launching Gradio: {e}", "ERROR")
finally:
    cleanup_process()
    log_message("Launch cell finished.")
# Out:
# [2025-06-26 19:13:30] [INFO] Starting AnxLight v3 Launch Cell
# [2025-06-26 19:13:30] [INFO] Launching: /content/AnxLight/scripts/main_gradio_app.py
# [2025-06-26 19:13:30] [INFO] Log file: /content/anxlight_logs_20250626_191214/gradio_app.log
# [2025-06-26 19:13:30] [INFO] Waiting for Gradio URL...
