# %% [markdown]
# # AnxLight Launcher v0.0.5 (v3 Architecture)
# ### Cell 1: Pre-Flight Setup
# This cell clones/updates the AnxLight repository and runs the `scripts/pre_flight_setup.py` script. This script handles VENV creation, all dependency installations (Gradio, etc.), tunneling clients, and installation of all supported WebUIs. Run this cell first and wait for it to complete. This cell is designed to be run once, or infrequently when major updates to WebUIs or core dependencies are needed.

# %%
# @title Cell 1: AnxLight v3 Pre-Flight Setup
# Cell 1: Pre-Flight Setup (v3)
import os
import subprocess
from pathlib import Path
import sys

print("--- AnxLight v3 Pre-Flight Setup Cell ---")

# --- Configuration ---
REPO_URL = "https://github.com/drf0rk/AnxLight.git"
REPO_DIR_NAME = "AnxLight"
BRANCH_NAME = "main"

# --- 1. Clone/Update Repository ---
print(f"--- Ensuring latest repository code from branch: {BRANCH_NAME} ---")
base_dir = Path("/content")
repo_path = base_dir / REPO_DIR_NAME

if not repo_path.exists():
    print(f"Cloning repository '{REPO_URL}' (branch: {BRANCH_NAME}) into '{repo_path}'...")
    subprocess.run(["git", "clone", "-b", BRANCH_NAME, REPO_URL, str(repo_path)], check=True)
else:
    print(f"Repository already exists at '{repo_path}'. Fetching updates from branch '{BRANCH_NAME}'...")
    os.chdir(str(repo_path))
    subprocess.run(["git", "fetch", "origin"], check=True)
    subprocess.run(["git", "checkout", BRANCH_NAME], check=True)
    subprocess.run(["git", "reset", "--hard", f"origin/{BRANCH_NAME}"], check=True)
    subprocess.run(["git", "pull", "origin", BRANCH_NAME], check=True)

os.chdir(str(repo_path))
print(f"Current directory: {os.getcwd()}")

# --- 2. Execute Pre-Flight Setup Script ---
print("\n--- Executing Pre-Flight Setup Script (scripts/pre_flight_setup.py) ---")
pre_flight_script_path = os.path.join(os.getcwd(), "scripts", "pre_flight_setup.py")

if os.path.exists(pre_flight_script_path):
    print(f"Running: {sys.executable} {pre_flight_script_path}")
    # Using Popen to stream output in real-time
    process = subprocess.Popen([sys.executable, pre_flight_script_path],
                               stdout=subprocess.PIPE,
                               stderr=subprocess.STDOUT,
                               text=True,
                               bufsize=1,
                               universal_newlines=True)
    for line in process.stdout:
        print(line, end='')
    process.wait()
    if process.returncode != 0:
        print(f"!!! ERROR: Pre-flight setup script failed with exit code {process.returncode}. Check output above. !!!")
    else:
        print("--- Pre-Flight Setup Script completed successfully. ---")
else:
    print(f"!!! ERROR: scripts/pre_flight_setup.py not found at {pre_flight_script_path}. Cannot proceed. !!!")

print("\n--- AnxLight Cell 1 (Pre-Flight Setup) Complete ---")
print("If no errors above, you can now run Cell 2 to launch the Gradio application.")
# Out:
# --- AnxLight v3 Pre-Flight Setup Cell ---
# --- Ensuring latest repository code from branch: main ---
# Repository already exists at '/content/AnxLight'. Fetching updates from branch 'main'...
# Current directory: /content/AnxLight
#
# --- Executing Pre-Flight Setup Script (scripts/pre_flight_setup.py) ---
# Running: /usr/bin/python3 /content/AnxLight/scripts/pre_flight_setup.py
# --- AnxLight Pre-Flight Setup ---
# AnxLight System Version: 3.0.0-alpha
# ---------------------------------
#
# --- Pre-Step: Ensuring essential system packages are installed ---
# Checking for required packages: ['python3-venv', 'aria2', 'unzip']
# Executing: sudo apt-get update -y in .
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Executing: sudo apt-get install -y python3-venv aria2 unzip in .
# Reading package lists...
# Building dependency tree...
# Reading state information...
# aria2 is already the newest version (1.36.0-1).
# unzip is already the newest version (6.0-26ubuntu3.2).
# python3-venv is already the newest version (3.10.6-1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# System packages checked/installed successfully.
#
# --- Step 1: Updating AnxLight Repository ---
# Executing: git pull in .
# Already up to date.
#
# --- Step 2: Setting up Virtual Environment ---
# Virtual environment already exists at: ./anxlight_venv
# VENV Python executable path: ./anxlight_venv/bin/python
#
# --- Step 2b: Verifying/Installing pip in Virtual Environment ---
# Executing: ./anxlight_venv/bin/python -m pip --version in .
# pip 25.1.1 from /content/AnxLight/anxlight_venv/lib/python3.11/site-packages/pip (python 3.11)
# pip is already installed in the VENV.
#
# --- Step 3: Installing Core Dependencies into VENV (anxlight_venv) ---
# Executing: ./anxlight_venv/bin/python -m pip install --upgrade gradio in .
# Requirement already satisfied: gradio in ./anxlight_venv/lib/python3.11/site-packages (5.34.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.115.13)
# Requirement already satisfied: ffmpy in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.3 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (1.10.3)
# Requirement already satisfied: groovy~=0.1 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.33.1)
# Requirement already satisfied: jinja2<4.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (2.3.1)
# Requirement already satisfied: orjson~=3.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (2.3.0)
# Requirement already satisfied: pillow<12.0,>=8.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (4.14.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio) (0.34.3)
# Requirement already satisfied: fsspec in ./anxlight_venv/lib/python3.11/site-packages (from gradio-client==1.10.3->gradio) (2025.5.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in ./anxlight_venv/lib/python3.11/site-packages (from gradio-client==1.10.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in ./anxlight_venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in ./anxlight_venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anxlight_venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anxlight_venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./anxlight_venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./anxlight_venv/lib/python3.11/site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./anxlight_venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: certifi in ./anxlight_venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in ./anxlight_venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./anxlight_venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (1.1.5)
# Requirement already satisfied: six>=1.5 in ./anxlight_venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./anxlight_venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./anxlight_venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./anxlight_venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.5.0)
# Executing: ./anxlight_venv/bin/python -m pip install --upgrade pyngrok in .
# Requirement already satisfied: pyngrok in ./anxlight_venv/lib/python3.11/site-packages (7.2.11)
# Requirement already satisfied: PyYAML>=5.1 in ./anxlight_venv/lib/python3.11/site-packages (from pyngrok) (6.0.2)
# Executing: ./anxlight_venv/bin/python -m pip install --upgrade huggingface-hub in .
# Requirement already satisfied: huggingface-hub in ./anxlight_venv/lib/python3.11/site-packages (0.33.1)
# Requirement already satisfied: filelock in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./anxlight_venv/lib/python3.11/site-packages (from huggingface-hub) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anxlight_venv/lib/python3.11/site-packages (from requests->huggingface-hub) (2025.6.15)
#
# --- Step 4: Checking for Tunneling Clients ---
# Checking for cloudflared...
# -> cloudflared not found or accessible in PATH. Instructions:
# Executing: echo 'Please install cloudflared manually: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/install-and-setup/installation/' in .
# Please install cloudflared manually: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/install-and-setup/installation/
# Checking for ngrok...
# -> ngrok not found or accessible in PATH. Instructions:
# Executing: echo 'pyngrok handles its own ngrok binary. If a system-wide ngrok is needed, install it manually.' in .
# pyngrok handles its own ngrok binary. If a system-wide ngrok is needed, install it manually.
#
# --- Step 5: Installing All Supported WebUIs ---
#
# -- Installing A1111 --
# Running setup for A1111 using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/A1111.py in .
# --- AnxLight A1111 UI Installer Script ---
# --- [A1111.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip ---
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
#   To: /content/AnxLight/A1111.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip
# >> Target directory: /content/AnxLight
# >> Target filename: A1111.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="A1111.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/A1111.zip"
# >> Aria2c download successful for A1111.zip
# --- [A1111.py] Step 2: Unzipping /content/AnxLight/A1111.zip to /content/AnxLight/A1111 ---
# --- [A1111.py] Step 3: Removing /content/AnxLight/A1111.zip ---
# --- [A1111.py] Unpack finished, proceeding to download configuration ---
# --- [A1111.py] Cloning extensions into /content/AnxLight/A1111/extensions ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Viewer' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'adetailer' already exists. Skipping clone.
# Extension 'SD-Couple' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [A1111.py] Script finished ---
# -- Finished installation attempt for A1111 --
#
# -- Installing Classic --
# Running setup for Classic using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/Classic.py in .
# --- AnxLight Classic UI Installer Script ---
# --- [Classic.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip ---
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
#   To: /content/AnxLight/Classic.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip
# >> Target directory: /content/AnxLight
# >> Target filename: Classic.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="Classic.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/Classic.zip"
# >> Aria2c download successful for Classic.zip
# --- [Classic.py] Step 2: Unzipping /content/AnxLight/Classic.zip to /content/AnxLight/Classic ---
# --- [Classic.py] Step 3: Removing /content/AnxLight/Classic.zip ---
# --- [Classic.py] Unpack finished, proceeding to download configuration ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'adetailer' already exists. Skipping clone.
# Extension 'SD-Couple' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [Classic.py] Download configuration finished, proceeding to apply module fixes ---
# --- [Classic.py] Applied fixes to /content/AnxLight/Classic/modules/cmd_args.py ---
# --- [Classic.py] Script finished ---
# -- Finished installation attempt for Classic --
#
# -- Installing ComfyUI --
# Running setup for ComfyUI using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/ComfyUI.py in .
# -- Finished installation attempt for ComfyUI --
#
# -- Installing Forge --
# Running setup for Forge using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/Forge.py in .
# -- Finished installation attempt for Forge --
#
# -- Installing ReForge --
# Running setup for ReForge using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/ReForge.py in .
# --- AnxLight ReForge UI Installer Script (Note: ReForge development by Panchovix reportedly stopped) ---
# --- [ReForge.py] Step 1: Cloning WebUI from https://github.com/Panchovix/stable-diffusion-webui-reForge.git into /content/AnxLight/ReForge ---
# --- [ReForge.py] Directory /content/AnxLight/ReForge already exists. Assuming ReForge is already cloned. ---
# --- [ReForge.py] ReForge repository cloned. Further setup handled by its first launch. ---
# --- [ReForge.py] ReForge repository clone process finished. ---
# --- [ReForge.py] Downloading configuration files and extensions (review for ReForge compatibility) ---
# --- [ReForge.py] Cloning extensions into /content/AnxLight/ReForge/extensions (review for ReForge compatibility) ---
# Extension 'timer' already exists. Skipping clone.
# Extension 'anxety-theme' already exists. Skipping clone.
# Extension 'Civitai-Browser-Plus' already exists. Skipping clone.
# Extension 'Image-Viewer' already exists. Skipping clone.
# Extension 'Image-Info' already exists. Skipping clone.
# Extension 'SD-Hub' already exists. Skipping clone.
# Extension 'Regional-Prompter' already exists. Skipping clone.
# --- [ReForge.py] Script finished ---
# -- Finished installation attempt for ReForge --
#
# -- Installing SD-UX --
# Running setup for SD-UX using ./anxlight_venv/bin/python...
# Executing: ./anxlight_venv/bin/python scripts/UIs/SD-UX.py in .
# --- AnxLight SD-UX UI Installer Script ---
# --- Note: Installation method and nature of 'SD-UX' needs verification. ---
# --- [SD-UX.py] Step 1: Downloading WebUI from https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip (assuming zip archive) ---
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Downloading: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
#   To: /content/AnxLight/SD-UX.zip
# > Cleaning URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# > Cleaned HuggingFace URL: https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip
# >> Target directory: /content/AnxLight
# >> Target filename: SD-UX.zip
# >> Attempting Aria2c: aria2c --header="User-Agent: Mozilla/5.0" --allow-overwrite=true --console-log-level=warn --summary-interval=0 --stderr=true -c -x16 -s16 -k1M -j5 --dir="/content/AnxLight" --out="SD-UX.zip" "https://huggingface.co/NagisaNao/ANXETY/resolve/main/SD-UX.zip"
# >> Aria2c download successful for SD-UX.zip
# --- [SD-UX.py] Step 2: Unzipping /content/AnxLight/SD-UX.zip to /content/AnxLight/SD-UX ---
# --- [SD-UX.py] Step 3: Removing /content/AnxLight/SD-UX.zip ---
# --- [SD-UX.py] Basic unzip complete. If this is Stability-AI/StableStudio, further Node.js/Yarn setup is needed. ---
# --- [SD-UX.py] Unpack process finished. ---
# --- [SD-UX.py] Downloading generic configuration files (review for SD-UX compatibility) ---
# --- [SD-UX.py] Generic extension download step skipped/placeholder for SD-UX. Needs verification. ---
# --- [SD-UX.py] Script finished ---
# -- Finished installation attempt for SD-UX --
#
# All WebUI installation scripts have been executed.
#
# --- Pre-Flight Setup Complete ---
# You should now be able to run Cell 2 of the AnxLight notebook to launch the Gradio UI.
# --- Pre-Flight Setup Script completed successfully. ---
#
# --- AnxLight Cell 1 (Pre-Flight Setup) Complete ---
# If no errors above, you can now run Cell 2 to launch the Gradio application.

# %% [markdown]
# ### Cell 2: Launch Gradio Application (v3)
# Run this cell only after Cell 1 has completed successfully. This cell launches the AnxLight Gradio UI for configuring and starting your WebUI session.

# %%
# @title Cell 2: AnxLight v3 Launch Gradio Application
# Cell 2: Launch Gradio Application (v3)
import os
import sys
import subprocess
import traceback
from pathlib import Path

PROJECT_ROOT_STR = "/content/AnxLight"
PROJECT_ROOT = Path(PROJECT_ROOT_STR)
APP_SCRIPT_RELATIVE_PATH = "scripts/main_gradio_app.py"
VENV_NAME = "anxlight_venv" # Must match VENV_NAME in pre_flight_setup.py

print(f"--- AnxLight v3 Launch Cell ---")

# Ensure CWD is project root
if Path.cwd() != PROJECT_ROOT:
    print(f"Changing directory to {PROJECT_ROOT_STR}")
    os.chdir(PROJECT_ROOT_STR)

scripts_path_abs = PROJECT_ROOT / "scripts"
if str(scripts_path_abs) not in sys.path:
    sys.path.insert(0, str(scripts_path_abs))

try:
    from anxlight_version import ANXLIGHT_LAUNCHER_NOTEBOOK_VERSION
    print(f"--- AnxLight Launcher Notebook v{ANXLIGHT_LAUNCHER_NOTEBOOK_VERSION} (v3) ---")
except ImportError:
    print(f"--- AnxLight Launcher Notebook (v3 - version import failed) ---")

print(f"Current Project Root (cwd for main_gradio_app.py): {Path.cwd()}")

# --- Environment Setup for main_gradio_app.py ---
print("\n--- Setting up Environment for Gradio Application ---")
os.environ['IS_COLAB'] = 'true'
os.environ['PROJECT_ROOT'] = PROJECT_ROOT_STR
os.environ['home_path'] = PROJECT_ROOT_STR
os.environ['scr_path'] = PROJECT_ROOT_STR
os.environ['settings_path'] = str(PROJECT_ROOT / 'anxlight_config.json')
os.environ['venv_path'] = str(PROJECT_ROOT / VENV_NAME)

modules_dir_abs = PROJECT_ROOT / 'modules'
current_python_path = os.environ.get('PYTHONPATH', '')
new_python_path_parts = [str(modules_dir_abs), PROJECT_ROOT_STR, str(scripts_path_abs)]
if current_python_path:
    for part in current_python_path.split(os.pathsep):
        if part and part not in new_python_path_parts:
            new_python_path_parts.append(part)
os.environ['PYTHONPATH'] = os.pathsep.join(new_python_path_parts)

print(f"[Notebook Cell 2] ENV PROJECT_ROOT: {os.environ['PROJECT_ROOT']}")
print(f"[Notebook Cell 2] ENV home_path: {os.environ['home_path']}")
print(f"[Notebook Cell 2] ENV scr_path: {os.environ['scr_path']}")
print(f"[Notebook Cell 2] ENV settings_path: {os.environ['settings_path']}")
print(f"[Notebook Cell 2] ENV venv_path: {os.environ['venv_path']}")
print(f"[Notebook Cell 2] Updated PYTHONPATH: {os.environ['PYTHONPATH']}")

app_to_run_path_str = str(PROJECT_ROOT / APP_SCRIPT_RELATIVE_PATH)
python_in_venv_path = Path(os.environ['venv_path']) / ('Scripts' if sys.platform == 'win32' else 'bin') / 'python'

print(f"\n--- Launching Gradio Application --- ")
if python_in_venv_path.exists():
    print(f"Using VENV Python: {python_in_venv_path}")
    print(f"Executing: {python_in_venv_path} {app_to_run_path_str}")
    try:
        # Use Popen to allow Gradio to run and stream output without blocking notebook execution indefinitely
        # if Gradio's share=True is used. Otherwise, subprocess.run can be fine.
        process_env = os.environ.copy()
        # The Gradio app will print its own share URL if successful
        # Using Popen to make it non-blocking for the notebook cell if Gradio runs in background
        # For debugging, it might be better to see all output directly:
        gradio_process = subprocess.Popen([str(python_in_venv_path), app_to_run_path_str],
                                        env=process_env,
                                        cwd=PROJECT_ROOT_STR,
                                        stdout=subprocess.PIPE,
                                        stderr=subprocess.STDOUT,
                                        text=True,
                                        bufsize=1,
                                        universal_newlines=True)
        # Stream Gradio output
        for line in gradio_process.stdout:
            print(line, end='')
        gradio_process.wait()
        if gradio_process.returncode != 0:
             print(f"Warning: main_gradio_app.py exited with code {gradio_process.returncode}")

    except Exception as e:
        print(f"An error occurred during launch with VENV python: {type(e).__name__}: {e}")
        traceback.print_exc()
else:
    print(f"ERROR: VENV Python executable not found at {python_in_venv_path}. Pre-flight setup (Cell 1) might have failed.")
    print("Cannot launch main_gradio_app.py without its VENV Python.")

print(f"\n--- Gradio app launch sequence in notebook complete. ---")
# Out:
# --- AnxLight v3 Launch Cell ---
# --- AnxLight Launcher Notebook v0.0.5 (v3) ---
# Current Project Root (cwd for main_gradio_app.py): /content/AnxLight
#
# --- Setting up Environment for Gradio Application ---
# [Notebook Cell 2] ENV PROJECT_ROOT: /content/AnxLight
# [Notebook Cell 2] ENV home_path: /content/AnxLight
# [Notebook Cell 2] ENV scr_path: /content/AnxLight
# [Notebook Cell 2] ENV settings_path: /content/AnxLight/anxlight_config.json
# [Notebook Cell 2] ENV venv_path: /content/AnxLight/anxlight_venv
# [Notebook Cell 2] Updated PYTHONPATH: /content/AnxLight/modules:/content/AnxLight:/content/AnxLight/scripts:/env/python
#
# --- Launching Gradio Application ---
# Using VENV Python: /content/AnxLight/anxlight_venv/bin/python
# Executing: /content/AnxLight/anxlight_venv/bin/python /content/AnxLight/scripts/main_gradio_app.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-2228744279.py in <cell line: 0>()
#      79                                         universal_newlines=True)
#      80         # Stream Gradio output
# ---> 81         for line in gradio_process.stdout:
#      82             print(line, end='')
#      83         gradio_process.wait()
#
# KeyboardInterrupt:
